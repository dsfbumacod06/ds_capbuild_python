# %%
# !pip install openpyxl
# !pip install gspread
# Out:
# Collecting gspread
#   Obtaining dependency information for gspread from https://files.pythonhosted.org/packages/17/4b/6280ce9b160286b3909f49ea1a2bd979d1a94d94164ad02edc22ede9da68/gspread-5.11.3-py3-none-any.whl.metadata
#   Downloading gspread-5.11.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from gspread) (2.23.2)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from gspread) (1.1.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from google-auth>=1.12.0->gspread) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from google-auth>=1.12.0->gspread) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from google-auth>=1.12.0->gspread) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\desktop\softwareengineering\capbuild\pythonn\ds_capbuild_python\.venv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2023.7.22)
# Using cached gspread-5.11.3-py3-none-any.whl (46 kB)
# Installing collected packages: gspread
# Successfully installed gspread-5.11.3

# %%
import pandas as pd

# %%
df1 = pd.read_excel('Test-Input-File.xlsx', sheet_name='SPIEL')

# %%
df_validation = df1.isnull()
df_validation
# Out:
#    TEST BED 1\nhttps://10.66.9.88:4432/LinkWorkbench/  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
#
#    TEST BED 2\nhttps://10.237.196.74:4432/LinkWorkbench/  PROD MPID  \
# 0                                              False           True
# 1                                              False           True
# 2                                              False           True
# 3                                              False           True
# 4                                              False           True
# 5                                              False           True
#
#    Message Name  Current Spiel  New Spiel  Status  Character Count
# 0         False           True      False    True            False
# 1         False           True      False    True            False
# 2         False           True      False    True            False
# 3         False           True      False    True            False
# 4         False           True      False    True            False
# 5         False          False      False    True            False

# %%
print(all(df_validation['PROD MPID']))  # should be true
print(all(df_validation['Status']))     # should be true
print(any(df_validation['New Spiel']))  # should be false
print(any(df_validation['Message Name']))  #should be false
# Out:
# True
# True
# False
# False

# %%
df2 = pd.read_excel('Test-Input-File-bad.xlsx', sheet_name='SPIEL')
df_validation2 = df2.isnull()
df_validation2
# Out:
#    TEST BED 1\nhttps://10.66.9.88:4432/LinkWorkbench/  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
#
#    TEST BED 2\nhttps://10.237.196.74:4432/LinkWorkbench/  PROD MPID  \
# 0                                              False           True
# 1                                              False           True
# 2                                              False           True
# 3                                              False           True
# 4                                              False           True
# 5                                              False          False
#
#    Message Name  Current Spiel  New Spiel  Status  Character Count
# 0          True           True      False    True            False
# 1         False           True       True    True            False
# 2         False           True      False    True            False
# 3         False           True      False    True            False
# 4         False           True      False    True            False
# 5         False          False      False    True            False

# %%
print(all(df_validation2['PROD MPID']))  # yields false
print(all(df_validation2['Status']))     # yields true
print(any(df_validation2['New Spiel']))  # yields true
print(any(df_validation2['Message Name']))  # yields true
# Out:
# False
# True
# True
# True

# %% [markdown]
# ---------------------------------------------------------

# %%
from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2 import service_account
from pprint import pprint
import pandas as pd

# %%
GSHEET_SCOPE = ['https://www.googleapis.com/auth/spreadsheets']
SERVICE_ACCOUNT_FILE = 'reflected-wind-264114-4b2bba4b561a.json'
spread_id = '1PpyCS3IPHqq2CZ_k3Y7dTs-H-Yty3IQjVTuuJraE2g4'  # spreadsheet

# %%
gsheet_credentials = service_account.Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE,
                                                                                   scopes=GSHEET_SCOPE)
service = build("sheets", "v4", credentials=gsheet_credentials)

# %%
response = service.spreadsheets().values().get(spreadsheetId=spread_id,
                                                        majorDimension="ROWS",
                                                        range='SPIEL').execute()

# %%
columns = response['values'][0]
data = response['values'][1:]
df = pd.DataFrame(data, columns=columns)
df
# Out:
#   TEST BED 1\nhttps://10.66.9.88:4432/LinkWorkbench/  \
# 0                                              71273
# 1                                              71293
# 2                                              71294
# 3                                              71295
# 4                                              71296
# 5                                              71297
#
#   TEST BED 2\nhttps://10.237.196.74:4432/LinkWorkbench/ PROD MPID  \
# 0                                              35141
# 1                                              35161
# 2                                              35181
# 3                                              35201
# 4                                              35202
# 5                                              35221
#
#             Message Name                                      Current Spiel  \
# 0     AMAX_UTANG_P1ANS20
# 1      AMAX_UTANG_P1FB10
# 2  AMAX_UTANG_P1TIKTOK10
# 3      AMAX_UTANG_P1YT10
# 4      AMAX_UTANG_P1ML10
# 5       AMAX_UTANG_ANS20  Pwede mo nang magamit ang iyong hiniram na UTA...
#
#                                            New Spiel Status Character Count
# 0  Pwede mo nang magamit ang iyong hiniram na ANS...                    345
# 1  Pwede mo nang magamit ang iyong hiniram na FB1...                    261
# 2  Pwede mo nang magamit ang iyong hiniram na TIK...                    267
# 3  Pwede mo nang magamit ang iyong hiniram na YT1...                    260
# 4  Pwede mo nang magamit ang iyong hiniram na ML1...                    267
# 5  Pwede mo nang magamit ang iyong hiniram na ANS...                    345

# %%
df_validation = df.isin(["", None, 0])
df_validation
# Out:
#    TEST BED 1\nhttps://10.66.9.88:4432/LinkWorkbench/  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
#
#    TEST BED 2\nhttps://10.237.196.74:4432/LinkWorkbench/  PROD MPID  \
# 0                                              False           True
# 1                                              False           True
# 2                                              False           True
# 3                                              False           True
# 4                                              False           True
# 5                                              False           True
#
#    Message Name  Current Spiel  New Spiel  Status  Character Count
# 0         False           True      False    True            False
# 1         False           True      False    True            False
# 2         False           True      False    True            False
# 3         False           True      False    True            False
# 4         False           True      False    True            False
# 5         False          False      False    True            False

# %%
len(df['PROD MPID'].iloc[0])
# Out:
# 0

# %%
df[df['*'].__str__.len() == 0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Desktop\SoftwareEngineering\CapBuild\Pythonn\ds_capbuild_python\suplementary-packages\gsheet-api-with-pandas\notebook.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/SoftwareEngineering/CapBuild/Pythonn/ds_capbuild_python/suplementary-packages/gsheet-api-with-pandas/notebook.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> df[df.__str__.len() == 0]
#
# AttributeError: 'method-wrapper' object has no attribute 'len'

# %%
import gspread

# %%
sa = gspread.service_account(filename=SERVICE_ACCOUNT_FILE)
sh = sa.open_by_key(spread_id)
wks = sh.worksheet('SPIEL')
# wks.get_all_records()

# %%
df = pd.DataFrame(wks.get_all_records())

# %%
df
# Out:
#    TEST BED 1\nhttps://10.66.9.88:4432/LinkWorkbench/  \
# 0                                              71273
# 1                                              71293
# 2                                              71294
# 3                                              71295
# 4                                              71296
# 5                                              71297
#
#    TEST BED 2\nhttps://10.237.196.74:4432/LinkWorkbench/ PROD MPID  \
# 0                                              35141
# 1                                              35161
# 2                                              35181
# 3                                              35201
# 4                                              35202
# 5                                              35221
#
#             Message Name                                      Current Spiel  \
# 0     AMAX_UTANG_P1ANS20
# 1      AMAX_UTANG_P1FB10
# 2  AMAX_UTANG_P1TIKTOK10
# 3      AMAX_UTANG_P1YT10
# 4      AMAX_UTANG_P1ML10
# 5       AMAX_UTANG_ANS20  Pwede mo nang magamit ang iyong hiniram na UTA...
#
#                                            New Spiel Status  Character Count
# 0  Pwede mo nang magamit ang iyong hiniram na ANS...                     345
# 1  Pwede mo nang magamit ang iyong hiniram na FB1...                     261
# 2  Pwede mo nang magamit ang iyong hiniram na TIK...                     267
# 3  Pwede mo nang magamit ang iyong hiniram na YT1...                     260
# 4  Pwede mo nang magamit ang iyong hiniram na ML1...                     267
# 5  Pwede mo nang magamit ang iyong hiniram na ANS...                     345

# %%
df_validation = df.isin(["", None, 0])
df_validation
# Out:
#    TEST BED 1\nhttps://10.66.9.88:4432/LinkWorkbench/  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
#
#    TEST BED 2\nhttps://10.237.196.74:4432/LinkWorkbench/  PROD MPID  \
# 0                                              False           True
# 1                                              False           True
# 2                                              False           True
# 3                                              False           True
# 4                                              False           True
# 5                                              False           True
#
#    Message Name  Current Spiel  New Spiel  Status  Character Count
# 0         False           True      False    True            False
# 1         False           True      False    True            False
# 2         False           True      False    True            False
# 3         False           True      False    True            False
# 4         False           True      False    True            False
# 5         False          False      False    True            False
